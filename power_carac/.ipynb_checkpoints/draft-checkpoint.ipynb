# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
#%pip install handcalcs

# %%
from handcalcs import *
from handcalcs import render
import handcalcs

# %%
def trigger (sig , thresh= None, transition= "rise", marginI = 20):
    arr=[0]
    if thresh is None: 
        thresh = (sig.max()+sig.min())/2
    for i in range(1, len(sig)):
        if transition =="rise":
            if sig[i-1] <thresh and sig[i] >= thresh and i > arr[-1]+marginI:
                arr.append(i)
        elif sig[i-1] >thresh and sig[i] <= thresh and i > arr[-1]+marginI:
            arr.append(i)
    return arr[1:]

# %%
# Initialization 
bl= '#1520c0' # blue 
rd= '#C62828' # red
fig_counter=1

# %%
# CONFIGURATIONS
#help(handcalcs.set_option)
handcalcs.set_option("latex_block_start", "$")
handcalcs.set_option("latex_block_end", "$")
handcalcs.set_option("math_environment_end", "aligned")
handcalcs.set_option("use_scientific_notation",True)

# %%
from figModelv2 import *

# %% [markdown]
# <h1 align="center"> Delta DPS-1125AB 1450W Reverse Engineering </h1>

# %% [markdown]
# <div align="center">
#   <img align="center" src = "figs/une.jpg">
# </div>

# %% [markdown]
# ## Table of contents

# %% [markdown]
# ## Overview

# %% [markdown]
# ## Transformer characterization

# %% [markdown]
# ### Np, Ns turns

# %%
fig_counter=  show_figure_pair_with_captions(fig_counter, 
                         img1="2026-06-07_19-45-10-824.png" , 
                        img2="2026-06-07_19-45-52-159.png" , 
                         caption1="",caption2="",
                         first_part_path="scope/", width="100%")
# Out:
#         <div style="display: flex; justify-content: center; align-items: stretch; width: 100%; gap: 1cm;">
#           <div style="flex: 1; text-align: center; max-width: 9cm; display: flex; flex-direction: column;">
#             <img src="scope/2026-06-07_19-45-10-824.png" style="width: 100%; height: auto;">
#             <div style="word-wrap: break-word; margin-top: auto;">
#                 <b>Figure 9 </b>
#             </div>
#           </div>
#           <div style="flex: 1; text-align: center; max-width: 9cm; display: flex; flex-direction: column;">
#             <img src="scope/2026-06-07_19-45-52-159.png" style="width: 100%; height: auto;">
#             <div style="word-wrap: break-word; margin-top: auto;">
#                 <b>Figure 10 </b>
#             </div>
#           </div>
#         </div>
#         <br>

# %%
# %%render
# Np = 50/4.52
# Out:
# $
# \begin{aligned}
# \mathrm{Np} &= \frac{ 50 }{ 4.52 } &= 11.062
# \end{aligned}
# $

# %%
fig_counter=  show_figure_pair_with_captions(fig_counter, 
                         img1="2026-06-08_13-00-47-046.png" , 
                        img2="2026-06-08_13-01-20-045.png" , 
                         caption1="",caption2="",
                         first_part_path="scope/", width="100%")
# Out:
#         <div style="display: flex; justify-content: center; align-items: stretch; width: 100%; gap: 1cm;">
#           <div style="flex: 1; text-align: center; max-width: 9cm; display: flex; flex-direction: column;">
#             <img src="scope/2026-06-08_13-00-47-046.png" style="width: 100%; height: auto;">
#             <div style="word-wrap: break-word; margin-top: auto;">
#                 <b>Figure 13 </b>
#             </div>
#           </div>
#           <div style="flex: 1; text-align: center; max-width: 9cm; display: flex; flex-direction: column;">
#             <img src="scope/2026-06-08_13-01-20-045.png" style="width: 100%; height: auto;">
#             <div style="word-wrap: break-word; margin-top: auto;">
#                 <b>Figure 14 </b>
#             </div>
#           </div>
#         </div>
#         <br>

# %%
# %%render
# Np = 50/4.62
# Ns = 15.7/4.62
# Out:
# $
# \begin{aligned}
# \mathrm{Np} &= \frac{ 50 }{ 4.62 } &= 10.823
# \\
# \mathrm{Ns} &= \frac{ 15.7 }{ 4.62 } &= 3.398
# \end{aligned}
# $

# %%
# %%render
# Np = 11
# Ns = 3
# Out:
# $
# \begin{aligned}
# \mathrm{Np} &= 11 \;
# \\
# \mathrm{Ns} &= 3 \;
# \end{aligned}
# $

# %% [markdown]
# ### Switching frequency

# %%
fig_counter=  show_figure_pair_with_captions(fig_counter, 
                         img1="2026-06-07_19-20-26-222.png" , 
           
                         caption1="",caption2="",
                         first_part_path="scope/", width="100%")
# Out:
#         <div style="width: 100%; text-align: center;">
#           <img src="scope/2026-06-07_19-20-26-222.png" style="max-width: 19cm; width: 100%; height: auto;">
#           <div style="word-wrap: break-word;">
#               <b>Figure 15 </b>
#           </div>
#         </div>
#         <br>

# %%
# %%render
# f_sw = 8830*10 # Hz
# Out:
# $
# \begin{aligned}
# f_{sw} &= 8830 \cdot 10 &= 88300 \; \;\textrm{(Hz)}
# \end{aligned}
# $

# %%
# %%render
# f_sw = 89140 # Hz
# Out:
# $
# \begin{aligned}
# f_{sw} &= 89140 \; \;\textrm{(Hz)}
# \end{aligned}
# $

# %% [markdown]
# ### Lm inductance

# %%
fig_counter=  show_figure_pair_with_captions(fig_counter, 
                         img1="2026-06-07_19-25-22-224.png" , 
                        img2="2026-06-07_19-26-04-993.png" , 
                         caption1="",caption2="",
                         first_part_path="scope/", width="100%")
# Out:
#         <div style="display: flex; justify-content: center; align-items: stretch; width: 100%; gap: 1cm;">
#           <div style="flex: 1; text-align: center; max-width: 9cm; display: flex; flex-direction: column;">
#             <img src="scope/2026-06-07_19-25-22-224.png" style="width: 100%; height: auto;">
#             <div style="word-wrap: break-word; margin-top: auto;">
#                 <b>Figure 5 </b>
#             </div>
#           </div>
#           <div style="flex: 1; text-align: center; max-width: 9cm; display: flex; flex-direction: column;">
#             <img src="scope/2026-06-07_19-26-04-993.png" style="width: 100%; height: auto;">
#             <div style="word-wrap: break-word; margin-top: auto;">
#                 <b>Figure 6 </b>
#             </div>
#           </div>
#         </div>
#         <br>

# %%
# %%render
# Delta_V = 382 # V
# Delta_I = 0.388 # A
# Delta_t= 1.14 # µs
# # v = L di/dt
# Lm= Delta_V  * (Delta_t/Delta_I) # µH
# Out:
# $
# \begin{aligned}
# \Delta_{V} &= 382 \; \;\textrm{(V)}
# \\
# \Delta_{I} &= 0.388 \; \;\textrm{(A)}
# \\
# \Delta_{t} &= 1.140 \; \;\textrm{(µs)}
# \\
# \mathrm{Lm} &= \Delta_{V} \cdot \left( \frac{ \Delta_{t} }{ \Delta_{I} } \right)  = 382 \cdot \left( \frac{ 1.140 }{ 0.388 } \right) &= 1122.371 \; \;\textrm{(µH)}
# \end{aligned}
# $

# %% [markdown]
# ### Leakage inductance

# %%
fig_counter=  show_figure_pair_with_captions(fig_counter, 
                         img1="2026-06-08_21-03-16-051.png" , 
                        img2="2026-06-08_21-02-47-862.png" , 
                         caption1="",caption2="",
                         first_part_path="scope/", width="100%")
# Out:
#         <div style="display: flex; justify-content: center; align-items: stretch; width: 100%; gap: 1cm;">
#           <div style="flex: 1; text-align: center; max-width: 9cm; display: flex; flex-direction: column;">
#             <img src="scope/2026-06-08_21-03-16-051.png" style="width: 100%; height: auto;">
#             <div style="word-wrap: break-word; margin-top: auto;">
#                 <b>Figure 3 </b>
#             </div>
#           </div>
#           <div style="flex: 1; text-align: center; max-width: 9cm; display: flex; flex-direction: column;">
#             <img src="scope/2026-06-08_21-02-47-862.png" style="width: 100%; height: auto;">
#             <div style="word-wrap: break-word; margin-top: auto;">
#                 <b>Figure 4 </b>
#             </div>
#           </div>
#         </div>
#         <br>

# %%
# %%render
# Delta_V = 228 # V
# Delta_I = 9.8 # A
# Delta_t= 180 # ns
# # v = L di/dt
# L_k= Delta_V  * (Delta_t/Delta_I) # nH leakage
# Out:
# $
# \begin{aligned}
# \Delta_{V} &= 228 \; \;\textrm{(V)}
# \\
# \Delta_{I} &= 9.800 \; \;\textrm{(A)}
# \\
# \Delta_{t} &= 180 \; \;\textrm{(ns)}
# \\
# L_{k} &= \Delta_{V} \cdot \left( \frac{ \Delta_{t} }{ \Delta_{I} } \right)  = 228 \cdot \left( \frac{ 180 }{ 9.800 } \right) &= 4187.755 \; \;\textrm{(nH leakage)}
# \end{aligned}
# $

# %%
# %%render
# leakage = 100*(L_k*1e-3)/Lm # \%
# Out:
# $
# \begin{aligned}
# \mathrm{leakage} &= 100 \cdot \frac{ L_{k} \cdot 1 \times 10 ^ {-3} }{ \mathrm{Lm} }  = 100 \cdot \frac{ 4187.755 \cdot 1 \times 10 ^ {-3} }{ 1122.371 } &= 0.373 \; \;\textrm{(\%)}
# \end{aligned}
# $
